# %% [markdown]
# # Imports

# %%
import sys
sys.path.append('../')
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 500)

import spacy
from spacy.lang.en import English
from spacy.attrs import POS
nlp = spacy.load('en_core_web_lg')

# %%
from nlp_utils import get_feats, lemmatize_doc
from gensim.models.tfidfmodel import TfidfModel
from gensim.corpora import Dictionary
from gensim.matutils import sparse2full

# %% [markdown]
# TODO: do something more principled here...

# %%
def stop (t) :
    return t.is_stop or t.lemma_ in ['person', 'tangrams', 'tangram', 'look', 'like', 'tap', 'choose', 'zzz', 'xxx', 'yyy', 'pick', 'guy', 'blue', 'box']

# %% [markdown]
# # pre-process text by lemmatizing

# %%
d_raw = pd.read_csv('../data/deidentified/combined_clean.csv', encoding='latin-1')

# %%
d_raw['text'] = [nlp(text) for text in d_raw['utterance']]
d_raw['non_stop_text'] = [[token for token in text if not token.is_stop] for text in d_raw['text']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-56c947b68ba9> in <module>
# ----> 1 d_raw['text'] = [nlp(text) for text in d_raw['utterance']]
#       2 d_raw['non_stop_text'] = [[token for token in text if not token.is_stop] for text in d_raw['text']]
#
# <ipython-input-5-56c947b68ba9> in <listcomp>(.0)
# ----> 1 d_raw['text'] = [nlp(text) for text in d_raw['utterance']]
#       2 d_raw['non_stop_text'] = [[token for token in text if not token.is_stop] for text in d_raw['text']]
#
# ~/miniconda3/lib/python3.7/site-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#     424         DOCS: https://spacy.io/api/language#call
#     425         """
# --> 426         if len(text) > self.max_length:
#     427             raise ValueError(
#     428                 Errors.E088.format(length=len(text), max_length=self.max_length)
#
# TypeError: object of type 'float' has no len()

# %%
d_raw['lemmatized_nonstop'] = [lemmatize_doc(parsed_text) for parsed_text in d_raw['non_stop_text']]

# %%
d_raw.head()

# %%
d = d_raw.copy()
gameidList = pd.unique(d.subid.ravel()).tolist()
tangramList = pd.unique(d.target.ravel()).tolist()

# %% [markdown]
# ### Look at where conventions were introduced

# %% [markdown]
# The first-order case is where you just look at how often final words occurred at each previous round (percentage).
#
# Then we can look at *first* round for each particular word...
#
# Then we can check who was speaker on that first round.
#
# TODO: check cases where the 'matcher' on a round may have introduced a word
#
# TODO: Split on PMI distribution as more systematic way of finding stop words...
#
# TODO: look at P(r + 1 | r) for local 'stickiness'
#
# TODO: potentially add back in messages sent after selection

# %%
rows = []

def stop (t) :
    return t.is_stop or t.lemma_ in ['person', 'look', 'like', 'tap', 'choose', 'zzz', 'xxx', 'yyy', 'pick', 'guy', 'blue', 'box']

# For each game, look at referring expressions produced by director on later round
for name, df in d.query('role == "director"').groupby(['subid', 'rep_num']) :
    for i, row in df.sort_values('target').reset_index().iterrows() :
        later_rep = row['rep_num']
        target = row['target']
        content_words = np.unique(
            [t.lemma_ for t in row.text 
             if t.pos_ in ["NOUN", "ADJ", 'VERB'] 
             and not stop(t)]
        )
        query_str = 'target == "{}"'.format(target)
        for j, word in enumerate(content_words) :
            for earlier_rep in range(1, later_rep) :
                earlier_df = d.query('rep_num == {} and role == "director" and subid == "{}"'
                                     .format(earlier_rep, name[0])).sort_values('target').reset_index()
                match = word in np.array(list(earlier_df.query(query_str)['lemmas'])).flatten()
                rows.append([row['experiment'], row['subid'], row['target'], row['person'], row['age'], earlier_rep, later_rep, word, match])

# %%
words_df = pd.DataFrame(rows,
    columns = ['experiment', 'subid', 'target', 'final_round_person', 'age',
               'earlier_rep', 'later_rep',  'word', 'match']
)

# %%
words_df.to_csv('../deidentified/word_matches.csv', index=False)

# %% [markdown]
# We can also look at the inverse: probability of words on current round appearing at end...

# %%
rows = []

# For each game, look at referring expressions produced by director on final round
for name, rep_df in d.query('role == "director"').groupby(['subid', 'rep_num']) :
    rep_df = rep_df.sort_values('target').reset_index()
    final_df = d.query('rep_num == 4 and role == "director" and subid == "{}"'.format(name[0])).sort_values('target').reset_index()
    
    # For each word used with each tangram, check whether it occured in each earlier round
    for i, row in rep_df.iterrows() :
        target = row['target']
        content_words = [t.lemma_ for t in row.text 
                         if t.pos_ in ["NOUN", "ADJ", 'VERB'] 
                         and not stop(t)]
        print('content', content_words)
        query_str = 'target == "{}"'.format(target)
        print(np.array(list(final_df.query(query_str)['lemmas'])).flatten())
        for j, word in enumerate(content_words) :
            final_match = word in np.array(list(final_df.query(query_str)['lemmas'])).flatten()
            rows.append([row['experiment'], row['subid'], row['rep_num'], row['target'], row['person'], row['age'], word, final_match])

# %%
words_df = pd.DataFrame(rows,
    columns = ['experiment', 'subid', 'rep_num', 'target', 'person', 'age', 'word', 'final_match']
)
words_df.to_csv('../deidentified/inverse_word_matches.csv')

# %% [markdown]
# # Examine semantic embeddings
# We'd like to pull out bag of words embeddings from NPs in each utterance in the cued dataset and cluster them for each tangram; expect to see different pairs in different parts of the space (i.e. to compute a d' for an 'idiosyncracy' or 'multiple equilibria' result) and also different utterances from single games closer together.

# %%
pd.read_csv('../data/deidentified/combined_clean.csv', encoding='latin-1')
# Out:
#       subid  trial  person      role target  rep_num    age   experiment  \
# 0         4      1   child   matcher     K1        1      6  adult-child
# 1         4      1  parent  director     K1        1      6  adult-child
# 2         4      2   child  director     C1        1      6  adult-child
# 3         4      2  parent   matcher     C1        1      6  adult-child
# 4         4      3  parent  director     I1        1      6  adult-child
# ...     ...    ...     ...       ...    ...      ...    ...          ...
# 4124    119     36   right  director     G1        4  adult  adult-adult
# 4125    119     37    left  director     E1        4  adult  adult-adult
# 4126    119     38   right  director     C1        4  adult  adult-adult
# 4127    119     39    left  director     D1        4  adult  adult-adult
# 4128    119     40   right  director     F1        4  adult  adult-adult
#
#                                               utterance  correct director
# 0                                                   NaN     True   parent
# 1     so mine looks like a guy with a little hat and...     True   parent
# 2     Mine looks like a guy mine looks kinda like a ...     True    child
# 3                                                   NaN     True    child
# 4     Mine looks like a guy carrying a tray saying w...     True   parent
# ...                                                 ...      ...      ...
# 4124                        it's not the person jumping     True   parent
# 4125                            it's the person jumping     True   parent
# 4126          it's the person kneeling all the way down     True   parent
# 4127                    it's the person in the airplane     True   parent
# 4128             it's not the person offering something     True   parent
#
# [4129 rows x 11 columns]

# %%
d_raw = (pd.read_csv('../data/deidentified/combined_clean.csv', encoding='latin-1')
         .query('utterance != "x"')
         .reset_index())

# %%
d_raw = d_raw[pd.notnull(d_raw.utterance)]

# %%
# concatenate
d_raw.groupby(['subid','trial', 'target', 'age', 'rep_num', 'experiment', 'director'])['utterance'].agg(utterance=' '.join).reset_index()
# Out:
#       subid  trial target    age  rep_num   experiment director  \
# 0         4      1     K1      6        1  adult-child   parent
# 1         4      2     C1      6        1  adult-child    child
# 2         4      3     I1      6        1  adult-child   parent
# 3         4      4     E1      6        1  adult-child    child
# 4         4      5     H1      6        1  adult-child   parent
# ...     ...    ...    ...    ...      ...          ...      ...
# 3252    119     36     G1  adult        4  adult-adult   parent
# 3253    119     37     E1  adult        4  adult-adult   parent
# 3254    119     38     C1  adult        4  adult-adult   parent
# 3255    119     39     D1  adult        4  adult-adult   parent
# 3256    119     40     F1  adult        4  adult-adult   parent
#
#                                               utterance
# 0     so mine looks like a guy with a little hat and...
# 1     Mine looks like a guy mine looks kinda like a ...
# 2     Mine looks like a guy carrying a tray saying w...
# 3              Mine looks like a person jumping for joy
# 4     Mine looks like someone's hungry and is like c...
# ...                                                 ...
# 3252                        it's not the person jumping
# 3253                            it's the person jumping
# 3254          it's the person kneeling all the way down
# 3255                    it's the person in the airplane
# 3256             it's not the person offering something
#
# [3257 rows x 8 columns]

# %%
d_raw['text'] = [nlp(text) for text in d_raw['utterance']]
# Out:
# /Users/rxdh/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
d_raw['contentful'] = [[t.lemma_ for t in text 
                        if t.is_alpha and 
                        t.pos_ not in ['PRON', 'DET', 'CCONJ', 'ADP', 'AUX', 'PUNCT']] 
                       for text in d_raw['text']]
# Out:
# /Users/rxdh/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
null_embedding = np.full((1,300), np.nan)
def get_feats(d_in, nlp, scramble = False) :
    # only look at director utterances
    d = d_in.copy()

    # initialize feature vector
    raw_avg_feats = np.array([]).reshape(0, 300)

    if scramble :
        d = scramble_words(d)
        
    for i, row in d.iterrows() :
        local_embedding = np.array([]).reshape(0, 300)
        for token in row['contentful'] :
            if nlp(token).has_vector and sum(nlp(token).vector) != 0:
                local_embedding = np.vstack((local_embedding, nlp(token).vector))
            else :
                print(i, '/', d.shape[0])
                print(row['utterance'])
                print(row['contentful'])
                print('no vector available:', nlp(token))

        # average them together, handling empty lists
        if row['contentful'] :
            raw_avg_embedding = np.nanmean(local_embedding, axis = 0) 
        else :
            
            raw_avg_embedding = null_embedding.copy()
            row['is_null'] = True
            
        # add to overall list
        raw_avg_feats = np.vstack((raw_avg_feats, raw_avg_embedding))
    return d, raw_avg_feats

# %%
meta, raw_avg_feats = get_feats(d_raw, nlp)
# Out:
# 119 / 3728
# I see a guy he's holding his hands that way this is the last one Like he's pointing his hands on the right I think he's like holding a gondora he's holding the square going that way Like he's not holding it in his hands like he's not holding anything he's not holding anything over there and he's not over there and he's not doing that he's over there It looks like a guy who has a square on his head and it looks like a square down pointing that way
# ['see', 'guy', 'hold', 'hand', 'way', 'last', 'one', 'like', 'point', 'hand', 'right', 'think', 'like', 'hold', 'gondora', 'hold', 'square', 'go', 'way', 'like', 'not', 'hold', 'hand', 'like', 'not', 'hold', 'not', 'hold', 'over', 'there', 'not', 'over', 'there', 'not', 'do', 'that', 'over', 'there', 'look', 'like', 'guy', 'square', 'head', 'look', 'like', 'square', 'point', 'way']
# no vector available: gondora
# 1085 / 3728
# this lady looks like she is wasasa, i'm just playing, it looks like she's wasasawing, it means laying down in my language
# ['lady', 'look', 'like', 'wasasa', 'just', 'play', 'look', 'like', 'wasasawe', 'mean', 'lay', 'language']
# no vector available: wasasa
# 1085 / 3728
# this lady looks like she is wasasa, i'm just playing, it looks like she's wasasawing, it means laying down in my language
# ['lady', 'look', 'like', 'wasasa', 'just', 'play', 'look', 'like', 'wasasawe', 'mean', 'lay', 'language']
# no vector available: wasasawe
# 1217 / 3728
# Mine looks like someone sitting and kneelingsquare
# ['mine', 'look', 'like', 'sit', 'kneelingsquare']
# no vector available: kneelingsquare
# 1594 / 3728
# Swinging
# ['swinge']
# no vector available: swinge
# /Users/rxdh/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:25: RuntimeWarning: Mean of empty slice
# 1626 / 3728
# It's a shape Someonerunning on their tippy toes Two feet With their knees they're running with their knees both feet back
# ['shape', 'someonerunne', 'tippy', 'toe', 'two', 'foot', 'knee', 'run', 'knee', 'foot', 'back']
# no vector available: someonerunne
# 1657 / 3728
# OK this is a person leaning over with his toushie out and a tray in his hand and he's wearing a hat
# ['ok', 'person', 'lean', 'toushie', 'tray', 'hand', 'wear', 'hat']
# no vector available: toushie
# 2066 / 3728
# this one is with somebodysomebody that has a hind legand their hand is out
# ['one', 'somebodysomebody', 'hind', 'legand', 'hand', 'out']
# no vector available: somebodysomebody
# 2105 / 3728
# This one is somebodythat's putting out their arm
# ['one', 'somebodythat', 'put', 'arm']
# no vector available: somebodythat
# 2122 / 3728
# i have two triangles on there and those things and i have a big triangle right there that doesn't have that line and i have a square on top that looks like this that these are legs and this is a head and he's goingjust like that and i see the person that was walking now again
# ['two', 'triangle', 'on', 'there', 'thing', 'big', 'triangle', 'right', 'there', 'line', 'square', 'top', 'look', 'like', 'that', 'leg', 'head', 'goingjust', 'like', 'see', 'person', 'walk', 'now', 'again']
# no vector available: goingjust
# 2154 / 3728
# can you pick the one that has no legs after they fell down? the one not jumping but the one wholooks like they're sitting on a box
# ['pick', 'one', 'leg', 'fall', 'one', 'not', 'jump', 'one', 'wholooks', 'like', 'sit', 'box']
# no vector available: wholooks
# 2234 / 3728
# alright in my blue box is the cat that's kinda on his hind legspick the cat because that's what's in my blue box not the sad guy
# ['alright', 'blue', 'box', 'cat', 'kinda', 'hind', 'legspick', 'cat', 'because', 'blue', 'box', 'not', 'sad', 'guy']
# no vector available: legspick
# 2446 / 3728
# This one's like a Apolloand it's sniffing
# ['one', 'like', 'Apolloand', 'sniff']
# no vector available: Apolloand
# 2586 / 3728
# so mine is the person holding with the triangle hat itkinda looks like a dog to me
# ['so', 'person', 'hold', 'triangle', 'hat', 'itkinda', 'look', 'like', 'dog']
# no vector available: itkinda
# 2651 / 3728
# okaythe person who's walking with the square head
# ['okaythe', 'person', 'walk', 'square', 'head']
# no vector available: okaythe
# 2753 / 3728
# this one looks likeit looks like someone who's jumping up to - and has their arms up in the air, it looks like they are kind of happy, or maybe, like playing basketball or somethingand they're like reaching up with one of their hands
# ['one', 'look', 'likeit', 'look', 'like', 'jump', 'arm', 'air', 'look', 'like', 'kind', 'of', 'happy', 'maybe', 'like', 'play', 'basketball', 'somethingand', 'like', 'reach', 'one', 'hand']
# no vector available: somethingand
# 2758 / 3728
# mine's kind of like you are runningor jogging or something like that
# ['mine', 'kind', 'of', 'like', 'runningor', 'jog', 'like']
# no vector available: runningor
# 2760 / 3728
# this one looks like someone who is sad and looking at the groundand maybe has like their hands in their pocket in that coat or something
# ['one', 'look', 'like', 'sad', 'look', 'groundand', 'maybe', 'like', 'hand', 'pocket', 'coat']
# no vector available: groundand
# 2774 / 3728
# okay so this guy is kind of like, like, you're likeputting feet up and relaxing
# ['okay', 'so', 'guy', 'kind', 'of', 'like', 'like', 'likeputte', 'foot', 'up', 'relax']
# no vector available: likeputte
# 2789 / 3728
# alright, this looks like it looked like an emperorholding something, so it looks like someone who's got a hat, like a triangle hat and a long robes and it's holding a bowl
# ['alright', 'look', 'like', 'look', 'like', 'emperorholde', 'look', 'like', 'get', 'hat', 'like', 'triangle', 'hat', 'long', 'robe', 'hold', 'bowl']
# no vector available: emperorholde
# 3028 / 3728
# this one looks like someone leaning forward and has a tailtail
# ['one', 'look', 'like', 'lean', 'forward', 'tailtail']
# no vector available: tailtail
# 3122 / 3728
# okay so the top, the top part is a square, it looks like it could be somebodythe shapes it's shaped like somebody isrunning
# ['okay', 'so', 'top', 'top', 'part', 'square', 'look', 'like', 'somebodythe', 'shape', 'shape', 'like', 'isrunne']
# no vector available: somebodythe
# 3122 / 3728
# okay so the top, the top part is a square, it looks like it could be somebodythe shapes it's shaped like somebody isrunning
# ['okay', 'so', 'top', 'top', 'part', 'square', 'look', 'like', 'somebodythe', 'shape', 'shape', 'like', 'isrunne']
# no vector available: isrunne
# 3132 / 3728
# okay this one looks like the shapesof somebody reading, like a book
# ['okay', 'one', 'look', 'like', 'shapesof', 'read', 'like', 'book']
# no vector available: shapesof
# 3153 / 3728
# it, there's a square on topit almost looks like somebody is kneeling
# ['square', 'topit', 'almost', 'look', 'like', 'kneel']
# no vector available: topit
# 3157 / 3728
# okay, it's somebody who's doing a jump, a a, doingjumping for joy
# ['okay', 'do', 'jump', 'a', 'doingjumpe', 'joy']
# no vector available: doingjumpe
# 3173 / 3728
# it's of somebodywhere the shapes look like somebody may be sitting down mhm or jumping for joy
# ['somebodywhere', 'shape', 'look', 'like', 'sit', 'mhm', 'jump', 'joy']
# no vector available: somebodywhere
# 3174 / 3728
# it's somebody who's , it's the president, who's telling his in order to help themhe did not to do that again it's the, it's the president is telling - yeah it's somebody who's tellingdon't do something again
# ['president', 'tell', 'order', 'to', 'help', 'themhe', 'not', 'to', 'again', 'president', 'tell', 'yeah', 'again']
# no vector available: themhe

# %%
meta
# Out:
#       index  subid  trial  person      role target  rep_num    age  \
# 1         1      4      1  parent  director     K1        1      6
# 2         2      4      2   child  director     C1        1      6
# 4         4      4      3  parent  director     I1        1      6
# 5         5      4      4   child  director     E1        1      6
# 6         6      4      5  parent  director     H1        1      6
# ...     ...    ...    ...     ...       ...    ...      ...    ...
# 4124   4124    119     36   right  director     G1        4  adult
# 4125   4125    119     37    left  director     E1        4  adult
# 4126   4126    119     38   right  director     C1        4  adult
# 4127   4127    119     39    left  director     D1        4  adult
# 4128   4128    119     40   right  director     F1        4  adult
#
#        experiment                                          utterance  correct  \
# 1     adult-child  so mine looks like a guy with a little hat and...     True
# 2     adult-child  Mine looks like a guy mine looks kinda like a ...     True
# 4     adult-child  Mine looks like a guy carrying a tray saying w...     True
# 5     adult-child           Mine looks like a person jumping for joy     True
# 6     adult-child  Mine looks like someone's hungry and is like c...     True
# ...           ...                                                ...      ...
# 4124  adult-adult                        it's not the person jumping     True
# 4125  adult-adult                            it's the person jumping     True
# 4126  adult-adult          it's the person kneeling all the way down     True
# 4127  adult-adult                    it's the person in the airplane     True
# 4128  adult-adult             it's not the person offering something     True
#
#      director                                               text  \
# 1      parent  (so, mine, looks, like, a, guy, with, a, littl...
# 2       child  (Mine, looks, like, a, guy, mine, looks, kinda...
# 4      parent  (Mine, looks, like, a, guy, carrying, a, tray,...
# 5       child  (Mine, looks, like, a, person, jumping, for, joy)
# 6      parent  (Mine, looks, like, someone, 's, hungry, and, ...
# ...       ...                                                ...
# 4124   parent                (it, 's, not, the, person, jumping)
# 4125   parent                     (it, 's, the, person, jumping)
# 4126   parent  (it, 's, the, person, kneeling, all, the, way,...
# 4127   parent           (it, 's, the, person, in, the, airplane)
# 4128   parent    (it, 's, not, the, person, offering, something)
#
#                                              contentful
# 1          [so, mine, look, like, guy, little, hat, go]
# 2     [Mine, look, like, guy, look, kinda, like, guy...
# 4       [Mine, look, like, guy, carry, tray, say, like]
# 5                 [Mine, look, like, person, jump, joy]
# 6        [Mine, look, like, hungry, like, please, more]
# ...                                                 ...
# 4124                                [not, person, jump]
# 4125                                     [person, jump]
# 4126                         [person, kneel, way, down]
# 4127                                 [person, airplane]
# 4128                               [not, person, offer]
#
# [3728 rows x 14 columns]

# %%
(meta
 .drop(columns = [ 'utterance', 'contentful'])
 .to_csv('../data/deidentified/meta_tangrams_embeddings.csv'))
np.save('../data/deidentified/feats_tangrams_embeddings_rawavg.npy', raw_avg_feats)

# %% [markdown]
# # Look at tsne visualization

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.manifold import MDS
from sklearn.decomposition import TruncatedSVD
tsne = TSNE(n_components = 2)
big_pca = PCA(n_components = 40)
viz_pca = PCA(n_components = 2)
mds = MDS(n_components=2)

# %%
embedding_viz = pd.DataFrame(
    columns = ['subid', 'target', 'trial', 'rep_num', 'x_tsne', 'y_tsne', 'x_mds', 'y_mds', 'feats_type']
)

for name, group in meta.reset_index(drop=True).groupby('target') :
    tangram_inds = np.array(group.index)
    feats = raw_avg_feats
    relevant_feats = feats[tangram_inds]
    
    # You can't run tsne with NANs, so we have to take them out and then add them back in...
    nan_rows = [i for i in range(relevant_feats.shape[0]) if pd.isna(relevant_feats[i,0])]
    nan_insert_rows = [k - lag for (lag, k) in enumerate(nan_rows)]
    X = np.ma.masked_invalid(relevant_feats)
    tsne_out = tsne.fit_transform(big_pca.fit_transform(np.ma.compress_rows(X)))
    tsne_out = np.insert(tsne_out, nan_insert_rows, np.nan, axis=0)
    X_tsne = pd.DataFrame(tsne_out, columns = ['x_tsne', 'y_tsne'], index=tangram_inds) 
    embedding_viz = embedding_viz.append(pd.concat([group, X_tsne], axis = 1), 
                                         ignore_index=True, sort=False)

# %%
embedding_viz.drop(columns=['text', 'contentful']).to_csv('../data/deidentified/tsne_embeddings.csv')
